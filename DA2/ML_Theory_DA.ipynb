# %% [markdown]
# <a href="https://colab.research.google.com/github/dhairyaostwal/CSE4020-Codes/blob/main/DA2/ML_Theory_DA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF
from sklearn.feature_extraction import text
from nltk.corpus import stopwords
from nltk import word_tokenize, pos_tag
from nltk.stem import WordNetLemmatizer
import re
import string

# %%
file = 'inaug_speeches.csv'
import chardet
with open(file, 'rb') as rawdata:
    result = chardet.detect(rawdata.read(100000))
result
# Out:
# {'confidence': 0.73, 'encoding': 'ISO-8859-1', 'language': ''}

# %%
# Using the dataset of inaugural speeches by US President obtained from here
# https://www.kaggle.com/datasets/adhok93/presidentialaddress

# expand pandas df column display width to enable easy inspection
pd.set_option('max_colwidth', 150)

# read in csv to dataframe
df = pd.read_csv(file, encoding='ISO-8859-1')

# visually inspect dataframe
df.head()
# Out:
#    Unnamed: 0               Name         Inaugural Address  \
# 0           4  George Washington   First Inaugural Address
# 1           5  George Washington  Second Inaugural Address
# 2           6         John Adams         Inaugural Address
# 3           7   Thomas Jefferson   First Inaugural Address
# 4           8   Thomas Jefferson  Second Inaugural Address
#
#                        Date  \
# 0  Thursday, April 30, 1789
# 1     Monday, March 4, 1793
# 2   Saturday, March 4, 1797
# 3  Wednesday, March 4, 1801
# 4     Monday, March 4, 1805
#
#                                                                                                                                                     text
# 0             Fellow-Citizens of the Senate and of the House of Representatives:    AMONG the vicissitudes incident to life no event could have fille...
# 1              Fellow Citizens:    I AM again called upon by the voice of my country to execute the functions of its Chief Magistrate. When the occas...
# 2                WHEN it was first perceived, in early times, that no middle course for America remained between unlimited submission to a foreign le...
# 3              Friends and Fellow-Citizens:    CALLED upon to undertake the duties of the first executive office of our country, I avail myself of th...
# 4                PROCEEDING, fellow-citizens, to that qualification which the Constitution requires before my entrance on the charge again conferred ...

# %% [markdown]
# ## Isolate Data to Topic Model

# %%
# Select Rows that are first term inaugural addresses
df = df.drop_duplicates(subset=['Name'], keep='first')

# Clean Up Index
df = df.reset_index()

# Select only President's Names and their Speeches
df = df[['Name', 'text']]

# Set Index to President's Names
df = df.set_index('Name')

# Visually Inspect
df.head()
# Out:
#                                                                                                                                                                     text
# Name
# George Washington             Fellow-Citizens of the Senate and of the House of Representatives:    AMONG the vicissitudes incident to life no event could have fille...
# John Adams                       WHEN it was first perceived, in early times, that no middle course for America remained between unlimited submission to a foreign le...
# Thomas Jefferson               Friends and Fellow-Citizens:    CALLED upon to undertake the duties of the first executive office of our country, I avail myself of th...
# James Madison                    UNWILLING to depart from examples of the most revered authority, I avail myself of the occasion now presented to express the profoun...
# James Monroe                     I SHOULD be destitute of feeling if I was not deeply affected by the strong proof which my fellow-citizens have given me of their co...

# %% [markdown]
# ## Cleaning Data

# %%
def clean_text_round1(text):
    '''Make text lowercase, remove text in square brackets, 
    remove punctuation, remove read errors,
    and remove words containing numbers.'''    
    text = text.lower()
    text = re.sub('\[.*?\]', ' ', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), ' ', text)
    text = re.sub('\w*\d\w*', ' ', text)
    text = re.sub('�', ' ', text)    
    return text

round1 = lambda x: clean_text_round1(x)

# Clean Speech Text
df["text"] = df["text"].apply(round1)

# Visually Inspect
df.head()
# Out:
#                                                                                                                                                                     text
# Name
# George Washington             fellow citizens of the senate and of the house of representatives     among the vicissitudes incident to life no event could have fille...
# John Adams                       when it was first perceived  in early times  that no middle course for america remained between unlimited submission to a foreign le...
# Thomas Jefferson               friends and fellow citizens     called upon to undertake the duties of the first executive office of our country  i avail myself of th...
# James Madison                    unwilling to depart from examples of the most revered authority  i avail myself of the occasion now presented to express the profoun...
# James Monroe                     i should be destitute of feeling if i was not deeply affected by the strong proof which my fellow citizens have given me of their co...

# %% [markdown]
# ## Preprocessing/Lemmatize

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
  
# Noun extract and lemmatize function

def nouns(text):
    # Given a string of text, tokenize the text 
    # and pull out only the nouns.
    # create mask to isolate words that are nouns
    is_noun = lambda pos: pos[:2] == 'NN'    
    
    # store function to split string of words 
    # into a list of words (tokens)
    tokenized = word_tokenize(text)
    # print(tokenized)    
    
    # store function to lemmatize each word
    wordnet_lemmatizer = WordNetLemmatizer()    
    
    # use list comprehension to lemmatize all words 
    # and create a list of all nouns
    all_nouns = [wordnet_lemmatizer.lemmatize(word) \
    for (word, pos) in pos_tag(tokenized) if is_noun(pos)] 
    
    #return string of joined list of nouns
    return ' '.join(all_nouns)
    
# Create dataframe of only nouns from speeches
data_nouns = pd.DataFrame(df.text.apply(nouns))

# Visually Inspect
data_nouns.head()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#                                                                                                                                                                     text
# Name
# George Washington  citizen senate house representative vicissitude incident life event anxiety notification order day month hand i country voice i veneration love re...
# John Adams         time course america submission legislature independence claim men reflection danger power fleet army contest dissension form government part count...
# Thomas Jefferson   friend citizen duty executive office country i myself presence portion fellow citizen thanks favor consciousness task talent presentiment greatnes...
# James Madison      example authority i myself occasion profound impression call country station duty i sanction mark confidence proceeding deliberate suffrage nation...
# James Monroe       i destitute i proof fellow citizen confidence office function expression opinion conduct service gratification sensibility estimate importance tru...

# %%
type(data_nouns)
# Out:
# pandas.core.frame.DataFrame

# %%
data_nouns['text'].head()
# Out:
# Name
# George Washington    citizen senate house representative vicissitude incident life event anxiety notification order day month hand i country voice i veneration love re...
# John Adams           time course america submission legislature independence claim men reflection danger power fleet army contest dissension form government part count...
# Thomas Jefferson     friend citizen duty executive office country i myself presence portion fellow citizen thanks favor consciousness task talent presentiment greatnes...
# James Madison        example authority i myself occasion profound impression call country station duty i sanction mark confidence proceeding deliberate suffrage nation...
# James Monroe         i destitute i proof fellow citizen confidence office function expression opinion conduct service gratification sensibility estimate importance tru...
# Name: text, dtype: object

# %%
text_for_word2vec = data_nouns['text'];

f = open("word2vec_file.txt", "w")
f.write(str(text_for_word2vec))
f.close()

#open and read the file after the appending:
f = open("word2vec_file.txt", "r")
text = f.read()
print(text)
# Out:
# Name
# George Washington         citizen senate house representative vicissitude incident life event anxiety notification order day month hand i country voice i veneration love re...
# John Adams                time course america submission legislature independence claim men reflection danger power fleet army contest dissension form government part count...
# Thomas Jefferson          friend citizen duty executive office country i myself presence portion fellow citizen thanks favor consciousness task talent presentiment greatnes...
# James Madison             example authority i myself occasion profound impression call country station duty i sanction mark confidence proceeding deliberate suffrage nation...
# James Monroe              i destitute i proof fellow citizen confidence office function expression opinion conduct service gratification sensibility estimate importance tru...
# George Bush               mr chief justice mr president vice president senator mitchell speaker congressman michel citizen neighbor friend man place heart history president...
# Bill Clinton              citizen today mystery renewal ceremony depth winter word world spring spring reborn world s democracy vision courage america founder independence ...
# George W. Bush            president clinton guest citizen transfer authority history country oath tradition beginning thank president clinton service nation thank vice pres...
# Barack Obama              citizen today task trust mindful sacrifice ancestor president bush service nation generosity cooperation transition american oath word tide prospe...
# Donald J. Trump           justice robert president carter president clinton president president american people world thank citizen america effort country promise people co...
# Name: text, dtype: object

# %% [markdown]
# ## TF-IDF Vectorizer

# %%
# Add additional stop words since we are recreating the document-term matrix
stop_noun = ["america", 'today', 'thing']
stop_words_noun_agg = text.ENGLISH_STOP_WORDS.union(stop_noun)

# Create a document-term matrix with only nouns# Store TF-IDF Vectorizer
tv_noun = TfidfVectorizer(stop_words=stop_words_noun_agg, ngram_range = (1,1), max_df = .8, min_df = .01)

# Fit and Transform speech noun text to a TF-IDF Doc-Term Matrix
data_tv_noun = tv_noun.fit_transform(data_nouns.text)

# Create data-frame of Doc-Term Matrix with nouns as column names
data_dtm_noun = pd.DataFrame(data_tv_noun.toarray(), columns=tv_noun.get_feature_names())

# Set President's Names as Index
data_dtm_noun.index = df.index

# Visually inspect Document Term Matrix
data_dtm_noun.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-129-b88af429975c> in <module>()
#       1 # Add additional stop words since we are recreating the document-term matrix
#       2 stop_noun = ["america", 'today', 'thing']
# ----> 3 stop_words_noun_agg = text.ENGLISH_STOP_WORDS.union(stop_noun)
#       4
#       5 # Create a document-term matrix with only nouns# Store TF-IDF Vectorizer
#
# AttributeError: 'str' object has no attribute 'ENGLISH_STOP_WORDS'

# %% [markdown]
# ## word2vec

# %%
# Python function to generate word vectors using Word2Vec

def generate_word2vec():
	# importing all necessary modules
	from nltk.tokenize import sent_tokenize, word_tokenize
	import warnings

	warnings.filterwarnings(action = 'ignore')

	import gensim
	from gensim.models import Word2Vec

	# Reads ‘alice.txt’ file
	sample = open("word2vec_file.txt", "r")
	s = sample.read()

	# Replaces escape character with space
	f = s.replace("\n", " ")

	data = []

	# iterate through each sentence in the file
	for i in sent_tokenize(f):
		temp = []
		
		# tokenize the sentence into words
		for j in word_tokenize(i):
			temp.append(j.lower())

		data.append(temp)

	# Create CBOW model
	model1 = gensim.models.Word2Vec(data, min_count = 1,
								size = 100, window = 5)

	# Print results
	print("Cosine similarity between 'citizen' " +
				"and 'duty' - CBOW : ",
		model1.similarity('citizen', 'duty'))
		
	print("Cosine similarity between 'countryman' " +
					"and 'oath' - CBOW : ",
		model1.similarity('countryman', 'oath'))

	print("Cosine similarity between 'citizen' " +
					"and 'world' - CBOW : ",
		model1.similarity('citizen', 'world'))

	# Create Skip Gram model
	model2 = gensim.models.Word2Vec(data, min_count = 1, size = 100,
												window = 5, sg = 1)

	# Print results
	print("Cosine similarity between 'citizen' " +
				"and 'duty' - Skip Gram : ",
		model1.similarity('citizen', 'duty'))
		
	print("Cosine similarity between 'countryman' " +
					"and 'oath' - Skip Gram : ",
		model1.similarity('countryman', 'oath'))

	print("Cosine similarity between 'citizen' " +
					"and 'world' - Skip Gram : ",
		model1.similarity('citizen', 'world'))
 

generate_word2vec()
# Out:
# Cosine similarity between 'citizen' and 'duty' - CBOW :  0.057460777
# Cosine similarity between 'countryman' and 'oath' - CBOW :  0.037355673
# Cosine similarity between 'citizen' and 'world' - CBOW :  0.16717038
# Cosine similarity between 'citizen' and 'duty' - Skip Gram :  0.057460777
# Cosine similarity between 'countryman' and 'oath' - Skip Gram :  0.037355673
# Cosine similarity between 'citizen' and 'world' - Skip Gram :  0.16717038

# %% [markdown]
# ## doc2vec

# %%
# Doc2Vec vectorised representation of a group of words taken collectively as a single unit

def generate_doc2vec():
  import gensim
  import gensim.downloader as api

  # preprocessing and cleaning data
  # f = open("word2vec_file.txt", "r", encoding='UTF-8')
  dataset = text
  print(dataset)
  data = dataset.split(' ')
  for i in data:
    if i =='':
      data.remove(i)

  def tagged_document(list_of_list_of_words):
    for i, list_of_words in enumerate(list_of_list_of_words):
        yield gensim.models.doc2vec.TaggedDocument(list_of_words, [i])

  data_for_training = list(tagged_document(data))
  print(data_for_training)
  print("\n")
  print(data_for_training[:1])
  model = gensim.models.doc2vec.Doc2Vec(vector_size=40, min_count=2, epochs=30)
  model.build_vocab(data_for_training)
  model.train(data_for_training, total_examples=model.corpus_count, epochs=model.epochs)
  print(model.infer_vector(['citizen', 'oath', 'countryman', 'world', 'duty','president']))


generate_doc2vec()
# Out:
# Name
# George Washington         citizen senate house representative vicissitude incident life event anxiety notification order day month hand i country voice i veneration love re...
# John Adams                time course america submission legislature independence claim men reflection danger power fleet army contest dissension form government part count...
# Thomas Jefferson          friend citizen duty executive office country i myself presence portion fellow citizen thanks favor consciousness task talent presentiment greatnes...
# James Madison             example authority i myself occasion profound impression call country station duty i sanction mark confidence proceeding deliberate suffrage nation...
# James Monroe              i destitute i proof fellow citizen confidence office function expression opinion conduct service gratification sensibility estimate importance tru...
# John Quincy Adams         compliance coeval existence constitution example predecessor career i citizen presence heaven solemnity obligation performance duty station i coun...
# Andrew Jackson            citizen duty i choice people myself occasion gratitude confidence inspires accountability situation magnitude interest convinces thanks honor retu...
# Martin Van Buren          fellow practice predecessor obligation i act trust avowal principle expression feeling charge example i footstep men superior happiness executive ...
# William Henry Harrison    retirement i residue life executive office nation i citizen oath constitution qualification performance duty obedience custom coeval government ex...
# James Knox Polk           citizen solicitation part i suffrage countryman office earth i gratitude confidence consideration period life predecessor diffidence discharge dut...
# Zachary Taylor            people office law oath constitution compliance time custom confidence respect countryman magistrate rank nation earth feeling gratitude acceptance...
# Franklin Pierce           countryman relief heart regret sorrow i position others circumstance i period destiny republic sense responsibility nothing apprehension i repair ...
# James Buchanan            citizen day solemn i office president state ability preserve protect constitution state office i god father wisdom firmness duty manner harmony fr...
# Abraham Lincoln           citizen state compliance custom government presence oath constitution state president execution office i present matter administration anxiety app...
# Ulysses S. Grant          citizen state suffrage office president state conformity constitution country oath office i oath reservation determination ability responsibility ...
[13]), TaggedDocument(words='month', tags=[14]), TaggedDocument(words='hand', tags=[15]), TaggedDocument(words='i', tags=[16]), TaggedDocument(words='country', tags=[17]), TaggedDocument(words='voice', tags=[18]), TaggedDocument(words='i', tags=[19]), TaggedDocument(words='veneration', tags=[20]), TaggedDocument(words='love', tags=[21]), TaggedDocument(words='re...\nJohn', tags=[22]), TaggedDocument(words='Adams', tags=[23]), TaggedDocument(words='time', tags=[24]), TaggedDocument(words='course', tags=[25]), TaggedDocument(words='america', tags=[26]), TaggedDocument(words='submission', tags=[27]), TaggedDocument(words='legislature', tags=[28]), TaggedDocument(words='independence', tags=[29]), TaggedDocument(words='claim', tags=[30]), TaggedDocument(words='men', tags=[31]), TaggedDocument(words='reflection', tags=[32]), TaggedDocument(words='danger', tags=[33]), TaggedDocument(words='power', tags=[34]), TaggedDocument(words='fleet', tags=[35]), TaggedDocument(words='army', tags=[36]), TaggedDocument(words='contest', tags=[37]), TaggedDocument(words='dissension', tags=[38]), TaggedDocument(words='form', tags=[39]), TaggedDocument(words='government', tags=[40]), TaggedDocument(words='part', tags=[41]), TaggedDocument(words='count...\nThomas', tags=[42]), TaggedDocument(words='Jefferson', tags=[43]), TaggedDocument(words='friend', tags=[44]), TaggedDocument(words='citizen', tags=[45]), TaggedDocument(words='duty', tags=[46]), TaggedDocument(words='executive', tags=[47]), TaggedDocument(words='office', tags=[48]), TaggedDocument(words='country', tags=[49]), TaggedDocument(words='i', tags=[50]), TaggedDocument(words='myself', tags=[51]), TaggedDocument(words='presence', tags=[52]), TaggedDocument(words='portion', tags=[53]), TaggedDocument(words='fellow', tags=[54]), TaggedDocument(words='citizen', tags=[55]), TaggedDocument(words='thanks', tags=[56]), TaggedDocument(words='favor', tags=[57]), TaggedDocument(words='consciousness', tags=[58]), TaggedDocument(words='task', tags=[59]), TaggedDocument(words='talent', tags=[60]), TaggedDocument(words='presentiment', tags=[61]), TaggedDocument(words='greatnes...\nJames', tags=[62]), TaggedDocument(words='Madison', tags=[63]), TaggedDocument(words='example', tags=[64]), TaggedDocument(words='authority', tags=[65]), TaggedDocument(words='i', tags=[66]), TaggedDocument(words='myself', tags=[67]), TaggedDocument(words='occasion', tags=[68]), TaggedDocument(words='profound', tags=[69]), TaggedDocument(words='impression', tags=[70]), TaggedDocument(words='call', tags=[71]), TaggedDocument(words='country', tags=[72]), TaggedDocument(words='station', tags=[73]), TaggedDocument(words='duty', tags=[74]), TaggedDocument(words='i', tags=[75]), TaggedDocument(words='sanction', tags=[76]), TaggedDocument(words='mark', tags=[77]), TaggedDocument(words='confidence', tags=[78]), TaggedDocument(words='proceeding', tags=[79]), TaggedDocument(words='deliberate', tags=[80]), TaggedDocument(words='suffrage', tags=[81]), TaggedDocument(words='nation...\nJames', tags=[82]), TaggedDocument(words='Monroe', tags=[83]), TaggedDocument(words='i', tags=[84]), TaggedDocument(words='destitute', tags=[85]), TaggedDocument(words='i', tags=[86]), TaggedDocument(words='proof', tags=[87]), TaggedDocument(words='fellow', tags=[88]), TaggedDocument(words='citizen', tags=[89]), TaggedDocument(words='confidence', tags=[90]), Tagg ...
# Jimmy Carter            0.000000  0.000000  0.000000     0.000000   0.000000
# Ronald Reagan           0.000000  0.000000  0.000000     0.000000   0.000000
# George Bush             0.000000  0.000000  0.000000     0.000000   0.000000
# Bill Clinton            0.000000  0.000000  0.000000     0.000000   0.000000
# George W. Bush          0.000000  0.000000  0.000000     0.000000   0.000000
# Barack Obama            0.000000  0.000000  0.000000     0.000000   0.000000
# Donald J. Trump         0.000000  0.000000  0.000000     0.000000   0.000000
#
#                         ...  wrongdoing   wrought      year       yes  \
# Name                    ...
# George Washington       ...    0.000000  0.000000  0.027063  0.000000
# John Adams              ...    0.000000  0.000000  0.089073  0.000000
# Thomas Jefferson        ...    0.000000  0.000000  0.000000  0.000000
# James Madison           ...    0.000000  0.000000  0.000000  0.000000
# James Monroe            ...    0.000000  0.000000  0.031220  0.000000
# John Quincy Adams       ...    0.000000  0.000000  0.117175  0.000000
# Andrew Jackson          ...    0.000000  0.000000  0.000000  0.000000
# Martin Van Buren        ...    0.000000  0.000000  0.040439  0.000000
# William Henry Harrison  ...    0.000000  0.000000  0.039877  0.000000
# James Knox Polk         ...    0.000000  0.000000  0.019730  0.000000
# Zachary Taylor          ...    0.000000  0.000000  0.000000  0.000000
# Franklin Pierce         ...    0.000000  0.000000  0.015654  0.000000
# James Buchanan          ...    0.000000  0.000000  0.031219  0.000000
# Abraham Lincoln         ...    0.000000  0.000000  0.047998  0.000000
# Ulysses S. Grant        ...    0.000000  0.000000  0.120435  0.000000
# Rutherford B. Hayes     ...    0.000000  0.000000  0.033614  0.000000
# James A. Garfield       ...    0.000000  0.000000  0.056591  0.000000
# Grover Cleveland        ...    0.000000  0.000000  0.023124  0.000000
# Benjamin Harrison       ...    0.000000  0.000000  0.032857  0.000000
# William McKinley        ...    0.000000  0.000000  0.124053  0.000000
# Theodore Roosevelt      ...    0.000000  0.000000  0.000000  0.000000
# William Howard Taft     ...    0.000000  0.000000  0.038348  0.000000
# Woodrow Wilson          ...    0.000000  0.000000  0.069515  0.000000
# Warren G. Harding       ...    0.000000  0.040342  0.000000  0.000000
# Calvin Coolidge         ...    0.000000  0.000000  0.038561  0.000000
# Herbert Hoover          ...    0.000000  0.000000  0.032106  0.000000
# Franklin D. Roosevelt   ...    0.062264  0.000000  0.019060  0.000000
# Harry S. Truman         ...    0.000000  0.000000  0.030833  0.000000
# Dwight D. Eisenhower    ...    0.000000  0.000000  0.000000  0.000000
# John F. Kennedy         ...    0.000000  0.000000  0.050048  0.000000
# Lyndon Baines Johnson   ...    0.000000  0.000000  0.063182  0.000000
# Richard Milhous Nixon   ...    0.000000  0.000000  0.108230  0.000000
# Jimmy Carter            ...    0.000000  0.000000  0.057756  0.000000
# Ronald Reagan           ...    0.000000  0.000000  0.048032  0.046995
# George Bush             ...    0.000000  0.000000  0.033284  0.048849
# Bill Clinton            ...    0.000000  0.000000  0.000000  0.000000
# George W. Bush          ...    0.000000  0.000000  0.036165  0.000000
# Barack Obama            ...    0.000000  0.000000  0.052369  0.000000
# William Henry Harrison  0.000000
# James Knox Polk         0.000000
# Zachary Taylor          0.000000
# Franklin Pierce         0.000000
# James Buchanan          0.000000
# Abraham Lincoln         0.000000
# Ulysses S. Grant        0.000000
# Rutherford B. Hayes     0.000000
# James A. Garfield       0.000000
# Grover Cleveland        0.000000
# Benjamin Harrison       0.000000
# William McKinley        0.000000
# Theodore Roosevelt      0.000000
# William Howard Taft     0.000000
# Woodrow Wilson          0.000000
# Warren G. Harding       0.000000
# Calvin Coolidge         0.000000
# Herbert Hoover          0.000000
# Franklin D. Roosevelt   0.000000
# Harry S. Truman         0.000000
# Dwight D. Eisenhower    0.000000
# John F. Kennedy         0.000000
# Lyndon Baines Johnson   0.000000
# Richard Milhous Nixon   0.000000
# Jimmy Carter            0.000000
# Ronald Reagan           0.000000
# George Bush             0.000000
# Bill Clinton            0.000000
# George W. Bush          0.000000
# Barack Obama            0.000000
# Donald J. Trump         0.000000
#
# [39 rows x 3214 columns]

# %% [markdown]
# ## Separating Dataset into Testing and Training

# %% [markdown]
# Splitting into 30% Testing and 70% Training Dataset

# %%
from sklearn.model_selection import train_test_split

X = data_dtm_noun[:18]
y = data_dtm_noun.iloc[19:37]
print(X,"\n\n", "y:\n", y)
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, test_size=0.30, random_state=42)
# Out:
#                         abandonment  abeyance   ability     abode  abraham  \
# Name
# George Washington          0.000000  0.000000  0.000000  0.000000      0.0
# John Adams                 0.000000  0.000000  0.000000  0.000000      0.0
# Thomas Jefferson           0.000000  0.000000  0.000000  0.000000      0.0
# James Madison              0.000000  0.000000  0.000000  0.000000      0.0
# James Monroe               0.000000  0.000000  0.000000  0.000000      0.0
# John Quincy Adams          0.000000  0.000000  0.022947  0.000000      0.0
# Andrew Jackson             0.000000  0.000000  0.048066  0.000000      0.0
# Martin Van Buren           0.000000  0.000000  0.042237  0.000000      0.0
# William Henry Harrison     0.000000  0.000000  0.020825  0.019508      0.0
# James Knox Polk            0.000000  0.000000  0.046367  0.028957      0.0
# Zachary Taylor             0.000000  0.000000  0.051987  0.000000      0.0
# Franklin Pierce            0.000000  0.000000  0.000000  0.000000      0.0
# James Buchanan             0.000000  0.000000  0.024455  0.000000      0.0
# Abraham Lincoln            0.000000  0.000000  0.018800  0.000000      0.0
# Ulysses S. Grant           0.000000  0.098359  0.141514  0.000000      0.0
# Rutherford B. Hayes        0.000000  0.000000  0.000000  0.000000      0.0
# James A. Garfield          0.000000  0.000000  0.000000  0.000000      0.0
# Grover Cleveland           0.062437  0.000000  0.000000  0.000000      0.0
#
#                          absence    absent  absolute  abstraction  abundance  \
# Name
# George Washington       0.000000  0.000000       0.0          0.0        0.0
# John Adams              0.000000  0.000000       0.0          0.0        0.0
# Thomas Jefferson        0.000000  0.000000       0.0          0.0        0.0
# James Madison           0.000000  0.000000       0.0          0.0        0.0
# James Monroe            0.000000  0.000000       0.0          0.0        0.0
# John Quincy Adams       0.000000  0.000000       0.0          0.0        0.0
# Andrew Jackson          0.000000  0.000000       0.0          0.0        0.0
# Martin Van Buren        0.000000  0.044035       0.0          0.0        0.0
# William Henry Harrison  0.016733  0.000000       0.0          0.0        0.0
# James Knox Polk         0.024837  0.000000       0.0          0.0        0.0
# Zachary Taylor          0.083542  0.000000       0.0          0.0        0.0
# Franklin Pierce         0.000000  0.000000       0.0          0.0        0.0
# James Buchanan          0.000000  0.000000       0.0          0.0        0.0
# Abraham Lincoln         0.000000  0.000000       0.0          0.0        0.0
# Ulysses S. Grant        0.000000  0.000000       0.0          0.0        0.0
# Rutherford B. Hayes     0.000000  0.000000       0.0          0.0        0.0
# James A. Garfield       0.000000  0.000000       0.0          0.0        0.0
# Grover Cleveland        0.000000  0.000000       0.0          0.0        0.0
#
#                         ...  wrongdoing  wrought      year  yes  yesterday  \
# Name                    ...
# George Washington       ...         0.0      0.0  0.027063  0.0        0.0
# John Adams              ...         0.0      0.0  0.089073  0.0        0.0
# Thomas Jefferson        ...         0.0      0.0  0.000000  0.0        0.0
# James Madison           ...         0.0      0.0  0.000000  0.0        0.0
# James Monroe            ...         0.0      0.0  0.031220  0.0        0.0
# John Quincy Adams       ...         0.0      0.0  0.117175  0.0        0.0
# Andrew Jackson          ...         0.0      0.0  0.000000  0.0        0.0
# Martin Van Buren        ...         0.0      0.0  0.040439  0.0        0.0
# William Henry Harrison  ...         0.0      0.0  0.039877  0.0        0.0
# James Knox Polk         ...         0.0      0.0  0.019730  0.0        0.0
# Zachary Taylor          ...         0.0      0.0  0.000000  0.0        0.0
# Franklin Pierce         ...         0.0      0.0  0.015654  0.0        0.0
# James Buchanan          ...         0.0      0.0  0.031219  0.0        0.0
# Abraham Lincoln         ...         0.0      0.0  0.047998  0.0        0.0
# Ulysses S. Grant        ...         0.0      0.0  0.120435  0.0        0.0
# Rutherford B. Hayes     ...         0.0      0.0  0.033614  0.0        0.0
# James A. Garfield       ...         0.0      0.0  0.056591  0.0        0.0
# Grover Cleveland        ...         0.0      0.0  0.023124  0.0        0.0
#
#                         york  yorktown  youth      zeal      zone
# Name
# George Washington        0.0  0.000000    0.0  0.000000  0.000000
# John Adams               0.0  0.000000    0.0  0.038005  0.000000
# Thomas Jefferson         0.0  0.000000    0.0  0.049602  0.000000
# James Madison            0.0  0.000000    0.0  0.000000  0.000000
# James Monroe             0.0  0.000000    0.0  0.033302  0.050994
# John Quincy Adams        0.0  0.000000    0.0  0.031247  0.000000
# Andrew Jackson           0.0  0.000000    0.0  0.065452  0.000000
# Martin Van Buren         0.0  0.000000    0.0  0.000000  0.000000
# William Henry Harrison   0.0  0.000000    0.0  0.000000  0.000000
# James Knox Polk          0.0  0.000000    0.0  0.000000  0.000000
# Zachary Taylor           0.0  0.000000    0.0  0.000000  0.000000
# Franklin Pierce          0.0  0.000000    0.0  0.000000  0.000000
# James Buchanan           0.0  0.000000    0.0  0.000000  0.000000
# Abraham Lincoln          0.0  0.000000    0.0  0.000000  0.000000
# Ulysses S. Grant         0.0  0.000000    0.0  0.000000  0.000000
# Rutherford B. Hayes      0.0  0.000000    0.0  0.000000  0.000000
# Warren G. Harding      ...    0.000000  0.040342  0.000000  0.000000
# Calvin Coolidge        ...    0.000000  0.000000  0.038561  0.000000
# Herbert Hoover         ...    0.000000  0.000000  0.032106  0.000000
# Franklin D. Roosevelt  ...    0.062264  0.000000  0.019060  0.000000
# Harry S. Truman        ...    0.000000  0.000000  0.030833  0.000000
# Dwight D. Eisenhower   ...    0.000000  0.000000  0.000000  0.000000
# John F. Kennedy        ...    0.000000  0.000000  0.050048  0.000000
# Lyndon Baines Johnson  ...    0.000000  0.000000  0.063182  0.000000
# Richard Milhous Nixon  ...    0.000000  0.000000  0.108230  0.000000
# Jimmy Carter           ...    0.000000  0.000000  0.057756  0.000000
# Ronald Reagan          ...    0.000000  0.000000  0.048032  0.046995
# George Bush            ...    0.000000  0.000000  0.033284  0.048849
# Bill Clinton           ...    0.000000  0.000000  0.000000  0.000000
# George W. Bush         ...    0.000000  0.000000  0.036165  0.000000
#
#                        yesterday  york  yorktown     youth      zeal  zone
# Name
# William McKinley        0.000000   0.0       0.0  0.000000  0.072178   0.0
# Theodore Roosevelt      0.000000   0.0       0.0  0.000000  0.000000   0.0
# William Howard Taft     0.000000   0.0       0.0  0.000000  0.000000   0.0
# Woodrow Wilson          0.000000   0.0       0.0  0.000000  0.000000   0.0
# Warren G. Harding       0.036248   0.0       0.0  0.000000  0.000000   0.0
# Calvin Coolidge         0.000000   0.0       0.0  0.000000  0.000000   0.0
# Herbert Hoover          0.000000   0.0       0.0  0.031413  0.000000   0.0
# Franklin D. Roosevelt   0.000000   0.0       0.0  0.000000  0.000000   0.0
# Harry S. Truman         0.000000   0.0       0.0  0.000000  0.000000   0.0
# Dwight D. Eisenhower    0.000000   0.0       0.0  0.000000  0.000000   0.0
# John F. Kennedy         0.000000   0.0       0.0  0.000000  0.000000   0.0
# Lyndon Baines Johnson   0.000000   0.0       0.0  0.000000  0.000000   0.0
# Richard Milhous Nixon   0.000000   0.0       0.0  0.105895  0.000000   0.0
# Jimmy Carter            0.000000   0.0       0.0  0.000000  0.000000   0.0
# Ronald Reagan           0.000000   0.0       0.0  0.000000  0.000000   0.0
# George Bush             0.000000   0.0       0.0  0.000000  0.000000   0.0
# Bill Clinton            0.061899   0.0       0.0  0.000000  0.000000   0.0
# George W. Bush          0.000000   0.0       0.0  0.000000  0.000000   0.0
#
# [18 rows x 3214 columns]

# %% [markdown]
# ## NNMF

# %%
def generate_NMF():
  def display_topics(model, feature_names, num_top_words, topic_names=None):
    for ix, topic in enumerate(model.components_):
        if not topic_names or not topic_names[ix]:
            print("\nTopic ", ix)
        else:
            print("\nTopic: '", topic_names[ix], "'")
        print(", ".join([feature_names[i]
                        for i in topic.argsort()[:-num_top_words - 1:-1]]))
        
  nmf_model = NMF(2)
  # Learn an NMF model for given Document Term Matrix 'V'
  # Extract the document-topic matrix 'W'
  doc_topic = nmf_model.fit_transform(Xtrain, ytrain)
  # Extract top words from the topic-term matrix 'H' display_topics(nmf_model, tv_noun.get_feature_names(), 5)
  display_topics(nmf_model, tv_noun.get_feature_names(), 10)

generate_NMF()
# Out:
# Topic  0
# constitution, union, principle, institution, opinion, peace, territory, object, administration, protection
#
# Topic  1
# dollar, debt, payment, question, determination, ability, office, year, method, pride

# %% [markdown]
# ## LDA

# %%
var = list(data_dtm_noun.columns)
var
# Out:
# ['abandonment',
#  'abeyance',
#  'ability',
#  'abode',
#  'abraham',
#  'absence',
#  'absent',
#  'absolute',
#  'abstraction',
#  'abundance',
#  'abuse',
#  'academy',
#  'accept',
#  'acceptance',
#  'access',
#  'accession',
#  'accident',
#  'accommodation',
#  'accomplishment',
#  'accord',
#  'accordance',
#  'account',
#  'accountability',
#  'accumulation',
#  'achievement',
#  'acknowledgment',
#  'acquiescence',
#  'acquisition',
#  'act',
#  'action',
#  'activism',
#  'activity',
#  'addiction',
#  'addition',
#  'address',
#  'adequate',
#  'adherence',
#  'adheres',
#  'adjunct',
#  'adjustment',
#  'administration',
#  'administrator',
#  'admiration',
#  'admission',
#  'admonition',
#  'adoption',
#  'adorns',
#  'advance',
#  'advancement',
#  'advantage',
#  'adventure',
#  'adversary',
#  'adverse',
#  'advice',
#  'adviser',
#  'advocacy',
#  'advocate',
#  'aegis',
#  'affair',
#  'affection',
#  'affectionate',
#  'affiliation',
#  'affirmation',
#  'affirms',
#  'affliction',
#  'afford',
#  'afghanistan',
#  'afield',
#  'afloat',
#  'aftermath',
#  'age',
#  'agency',
#  'agent',
#  'aggrandizement',
#  'aggravation',
#  'aggregate',
#  'aggression',
#  'aggressor',
#  'agitate',
#  'agitation',
#  'agony',
#  'agreement',
#  'agriculture',
#  'aid',
#  'aim',
#  'air',
#  'airport',
#  'alacrity',
#  'alarm',
#  'alien',
#  'alienation',
#  'aliment',
#  'ality',
#  'allegation',
#  'alleghanies',
#  'allegiance',
#  'alleviate',
#  'alliance',
#  'allusion',
#  'ally',
#  'almighty',
#  'aloof',
#  'altar',
#  'alteration',
#  'altercation',
#  'alternative',
#  'ambassador',
#  'ambiguity',
#  'ambition',
#  'ambush',
#  'amen',
#  'amendment',
#  'american',
#  'amity',
#  'amply',
#  'anarchy',
#  'ancestor',
#  'anchor',
#  'ancient',
#  'andes',
#  'angel',
#  'animation',
#  'animosity',
#  'annals',
#  'annexation',
#  'annexed',
#  'annihilate',
#  'anniversary',
#  'annoyance',
#  'answer',
#  'ant',
#  'antagonist',
#  'anthony',
#  'anticipation',
#  'antipathy',
#  'antiquity',
#  'anxiety',
#  'apollo',
#  'apology',
#  'appalling',
#  'appeal',
#  'appearance',
#  'appeasement',
#  'applicant',
#  'application',
#  'applies',
#  'appoint',
#  'appointee',
#  'appointment',
#  'appraisal',
#  'appreciation',
#  'apprehension',
#  'approach',
#  'approbation',
#  'appropriateness',
#  'appropriation',
#  'approval',
#  'april',
#  'aqueduct',
#  'arbitrament',
#  'arbitration',
#  'archipelago',
#  'architect',
#  'ardent',
#  'ardor',
#  'area',
#  'argonne',
#  'argument',
#  'arise',
#  'aristocracy',
#  'ark',
#  'arlington',
#  'arm',
#  'armament',
#  'army',
#  'arose',
#  'arraignment',
#  'arrange',
#  'arrangement',
#  'array',
#  'arrogance',
#  'arsenal',
#  'art',
#  'article',
#  'artifice',
#  'artillery',
#  'artisan',
#  'artist',
#  'asia',
#  'ask',
#  'aspect',
#  'aspiration',
#  'assault',
#  'assemblage',
#  'assembly',
#  'assent',
#  'assertion',
#  'assignment',
#  'assist',
#  'assistance',
#  'associate',
#  'association',
#  'assumption',
#  'assurance',
#  'assure',
#  'asunder',
#  'asylum',
#  'ate',
#  'athens',
#  'atmosphere',
#  'atom',
#  'atrocity',
#  'attachment',
#  'attack',
#  'attainment',
#  'attempt',
#  'attendant',
#  'attention',
#  'attitude',
#  'attorney',
#  'attribute',
#  'audacity',
#  'augmentation',
#  'augments',
#  'august',
#  'auspex',
#  'author',
#  'authority',
#  'autocracy',
#  'autonomy',
#  'auxiliary',
#  'availability',
#  'avenue',
#  'aver',
#  'avoidance',
#  'avowal',
#  'aware',
#  'ax',
#  'background',
#  'bacteria',
#  'badge',
#  'baker',
#  'balance',
#  'ballot',
#  'balm',
#  'baltimore',
#  'band',
#  'banishment',
#  'bank',
#  'banking',
#  'banner',
#  'baptism',
#  'bar',
#  'barbarian',
#  'barber',
#  'bare',
#  'bargain',
#  'barrier',
#  'base',
#  'basis',
#  'bastion',
#  'battalion',
#  'battle',
#  'battlefield',
#  'bay',
#  'beach',
#  'beachhead',
#  'beacon',
#  'bearing',
#  'beating',
#  'beauty',
#  'beckons',
#  'bedrock',
#  'befits',
#  'begets',
#  'beginning',
#  'behalf',
#  'belief',
#  'believer',
#  'believing',
#  'belligerent',
#  'belong',
#  'belonging',
#  'belongs',
#  'belove',
#  'benediction',
#  'benefactor',
#  'beneficence',
#  'beneficent',
#  'benefit',
#  'benevolence',
#  'benevolent',
#  'beseems',
#  'bestowal',
#  'better',
#  'bible',
#  'bicker',
#  'bigotry',
#  'billion',
#  'billow',
#  'bimetallism',
#  'bind',
#  'binding',
#  'bipartisanship',
#  'birth',
#  'birthright',
#  'bitter',
#  'bitterness',
#  'bless',
#  'blessing',
#  'blight',
#  'blood',
#  'bloodshed',
#  'bloody',
#  'blot',
#  'blotch',
#  'board',
#  'boast',
#  'boastfulness',
#  'boat',
#  'body',
#  'bold',
#  'boldness',
#  'bolivar',
#  'bona',
#  'bond',
#  'book',
#  'border',
#  'bosom',
#  'bound',
#  'boundary',
#  'bounty',
#  'box',
#  'boy',
#  'boycott',
#  'branch',
#  'brave',
#  'bravery',
#  'bread',
#  'break',
#  'breast',
#  'breath',
#  'breed',
#  'breeze',
#  'bridge',
#  'briefly',
#  'brighter',
#  'bring',
#  'britain',
#  'broil',
#  'brother',
#  'brotherhood',
#  'brutus',
#  'budget',
#  'building',
#  'bulk',
#  'bulwark',
#  'burden',
#  'bureau',
#  'burma',
#  'bush',
#  'business',
#  'bygone',
#  'cabby',
#  'cabinet',
#  'caesar',
#  'calamity',
#  'calculation',
#  'calendar',
#  'calm',
#  'calmly',
#  'calmness',
#  'camillus',
#  'camp',
#  'campaign',
#  'campfire',
#  'canal',
#  'candid',
#  'candidate',
#  'candle',
#  'candor',
#  'canton',
#  'canvas',
#  'capacity',
#  'cape',
#  'capital',
#  'capitalist',
#  'capitol',
#  'caprice',
#  'car',
#  'care',
#  'career',
#  'careful',
#  'cargo',
#  'carnage',
#  'carolina',
#  'carrier',
#  'carter',
#  'case',
#  'cash',
#  'casualty',
#  'catalogue',
#  'catastrophe',
#  'cathedral',
#  'cattle',
#  'cause',
#  'caution',
#  'cease',
#  'celebrate',
#  'celebration',
#  'cement',
#  'cemetery',
#  'census',
#  'centennial',
#  'center',
#  'century',
#  'cereal',
#  'ceremony',
#  'certainty',
#  'chain',
#  'chair',
#  'chalice',
#  'challenge',
#  'chamber',
#  'chance',
#  'change',
#  'changeless',
#  'changer',
#  'channel',
#  'chaos',
#  'chapter',
#  'character',
#  'charge',
#  'charity',
#  'chart',
#  'charter',
#  'chase',
#  'chattel',
#  'check',
#  'cheering',
#  'chest',
#  'chief',
#  'child',
#  'childhood',
#  'choice',
#  'chop',
#  'chord',
#  'chorus',
#  'chosin',
#  'christ',
#  'christian',
#  'christianity',
#  'christmas',
#  'church',
#  'churchill',
#  'ci',
#  'cincinnati',
#  'circle',
#  'circulation',
#  'circumstance',
#  'citement',
#  'citizenry',
#  'citizenship',
#  'city',
#  'civility',
#  'civilization',
#  'claim',
#  'clamor',
#  'clarification',
#  'class',
#  'clause',
#  'clay',
#  'clearcut',
#  'clearness',
#  'cleaves',
#  'clergy',
#  'clerk',
#  'climate',
#  'clime',
#  'clinching',
#  'clinton',
#  'clock',
#  'close',
#  'closeness',
#  'closer',
#  'closing',
#  'clothing',
#  'cloud',
#  'coal',
#  'coast',
#  'cocaine',
#  'code',
#  'coercion',
#  'coeval',
#  'coffer',
#  'coherence',
#  'coin',
#  'coinage',
#  'coincidence',
#  'cold',
#  'coldest',
#  'coleman',
#  'collaborator',
#  'collapse',
#  'collection',
#  'college',
#  'collision',
#  'colonel',
#  'colonial',
#  'colonist',
#  'colonization',
#  'colony',
#  'color',
#  'colossal',
#  'columbia',
#  'column',
#  'combat',
#  'combination',
#  'combine',
#  'comfort',
#  'comity',
#  'command',
#  'commander',
#  'commandment',
#  'commence',
#  'commencement',
#  'commensurate',
#  'commerce',
#  'commission',
#  'commissioner',
#  'commit',
#  'commitment',
#  'commodity',
#  'common',
#  'commonplace',
#  'commonwealth',
#  'communication',
#  'communion',
#  'communism',
#  'communist',
#  'community',
#  'compact',
#  'companion',
#  'company',
#  'comparative',
#  'comparison',
#  'compass',
#  'compassion',
#  'compassionate',
#  'compensation',
#  'competency',
#  'competent',
#  'competition',
#  'complaint',
#  'completeness',
#  'completion',
#  'complexity',
#  'compliance',
#  'complication',
#  'compliment',
#  'comports',
#  'composition',
#  'comprehension',
#  'compromise',
#  'compulsory',
#  'computation',
#  'comrade',
#  'conceive',
#  'concentration',
#  'concept',
#  'conception',
#  'concern',
#  'concernment',
#  'concert',
#  'concess',
#  'concession',
#  'conciliation',
#  'concise',
#  'conclusion',
#  'concord',
#  'concurrence',
#  'condition',
#  'conduct',
#  'confederacy',
#  'confederate',
#  'confederation',
#  'conference',
#  'confers',
#  'confess',
#  'confession',
#  'confidence',
#  'confident',
#  'configuration',
#  'confines',
#  'conflict',
#  'conformity',
#  'confrontation',
#  'confronts',
#  'confusion',
#  'congratulate',
#  'congratulation',
#  'congregation',
#  'congress',
#  'congressman',
#  'conjecture',
#  'connection',
#  'connive',
#  'conqueror',
#  'conquest',
#  'conscience',
#  'consciousness',
#  'consecration',
#  'consent',
#  'consequence',
#  'consequent',
#  'conservation',
#  'conservator',
#  'consider',
#  'considerate',
#  'consideration',
#  'consistent',
#  'consolation',
#  'consort',
#  'constant',
#  'constellation',
#  'constituent',
#  'constitution',
#  'constraint',
#  'construction',
#  'consul',
#  'consultation',
#  'consummation',
#  'consumption',
#  'contact',
#  'contain',
#  'contemplation',
#  'contempt',
#  'content',
#  'contention',
#  'contentment',
#  'contest',
#  'continent',
#  'contingency',
#  'continuance',
#  'continuation',
#  'continue',
#  'continuity',
#  'continuum',
#  'contract',
#  'contraction',
#  'contradistinction',
#  'contrary',
#  'contrast',
#  'contribute',
#  'contribution',
#  'control',
#  'controversy',
#  'convenience',
#  'convenient',
#  'convening',
#  'convention',
#  'conversion',
#  'conviction',
#  'convinces',
#  'convulsion',
#  'coolidge',
#  'cooperation',
#  'coordinate',
#  'copartnership',
#  'cordial',
#  'core',
#  'corn',
#  'corner',
#  'corporation',
#  'corpus',
#  'correct',
#  'correction',
#  'corrective',
#  'correspondent',
#  'corruption',
#  'cost',
#  'cotton',
#  'council',
#  'counsel',
#  'count',
#  'counter',
#  'counteraction',
#  'counterfeit',
#  'counting',
#  'countryman',
#  'courage',
#  'courier',
#  'course',
#  'court',
#  'courtesy',
#  'covenant',
#  'covet',
#  'cradle',
#  'creation',
#  'creator',
#  'credit',
#  'creditor',
#  'creed',
#  'crime',
#  'criminal',
#  'crisis',
#  'criticism',
#  'cromwell',
#  'crop',
#  'cross',
#  'crude',
#  'cruelty',
#  'crushing',
#  'ct',
#  'cultivation',
#  'cultivator',
#  'culture',
#  'cup',
#  'curiosity',
#  'currency',
#  'current',
#  'curtailment',
#  'curtii',
#  'custody',
#  'custom',
#  'cut',
#  'cycle',
#  'cynic',
#  'cynicism',
#  'dakota',
#  'dam',
#  'danger',
#  'dark',
#  'darkness',
#  'data',
#  'david',
#  'dawn',
#  'day',
#  'deadlock',
#  'deal',
#  'dealing',
#  'dealt',
#  'dear',
#  'death',
#  'debasement',
#  'debate',
#  'debt',
#  'debtor',
#  'decade',
#  'decadent',
#  'decay',
#  'deceit',
#  'december',
#  'decency',
#  'decent',
#  'decides',
#  'decii',
#  'decision',
#  'declaration',
#  'decline',
#  'decoration',
#  'decree',
#  'dedication',
#  'deed',
#  'deepening',
#  'deeper',
#  'defaulter',
#  'defeat',
#  'defeatism',
#  'defect',
#  'defend',
#  'defender',
#  'defense',
#  'deference',
#  'deficiency',
#  'deficit',
#  'defies',
#  'definite',
#  'definition',
#  'degeneration',
#  'degradation',
#  'degree',
#  'delano',
#  'delay',
#  'deliberate',
#  'deliberation',
#  'delicacy',
#  'delight',
#  'delinquency',
#  'delinquent',
#  'delirium',
#  'deliverance',
#  'delusion',
#  'demagogue',
#  'demand',
#  'democracy',
#  'democrat',
#  'demonstration',
#  'demoralization',
#  'demoralizing',
#  'denial',
#  'denies',
#  'denomination',
#  'depart',
#  'department',
#  'departure',
#  'depend',
#  'dependence',
#  'dependency',
#  'dependent',
#  'depends',
#  'depletion',
#  'deposit',
#  'depositary',
#  'depression',
#  'deprivation',
#  'depth',
#  'derives',
#  'descendant',
#  'desert',
#  'deserve',
#  'deserving',
#  'design',
#  'designation',
#  'desire',
#  'despair',
#  'despondence',
#  'despot',
#  'despotism',
#  'destination',
#  'destiny',
#  'destitute',
#  'destruction',
#  'destructive',
#  'detachment',
#  'determination',
#  'determine',
#  'detriment',
#  'detroit',
#  'development',
#  'deviation',
#  'device',
#  'devoti',
#  'devotion',
#  'devout',
#  'dew',
#  'diadem',
#  'diamond',
#  'diary',
#  'dictate',
#  'dictator',
#  'difference',
#  'differentiation',
#  'difficulty',
#  'diffidence',
#  'diffusion',
#  'dignifies',
#  'dignity',
#  'diligence',
#  'diligent',
#  'diminishes',
#  'dimness',
#  'din',
#  'dingley',
#  'diplomacy',
#  'direction',
#  'dirksen',
#  'dis',
#  'disaffection',
#  'disagreement',
#  'disarmament',
#  'disaster',
#  'disbursement',
#  'discernment',
#  'discharge',
#  'disciple',
#  'discipline',
#  'discontent',
#  'discord',
#  'discouragement',
#  'discovery',
#  'discrepancy',
#  'discretion',
#  'discrimination',
#  'discussion',
#  'disease',
#  'disguise',
#  'disinclination',
#  'disobedience',
#  'disorder',
#  'disorganization',
#  'dispassionate',
#  'dispensation',
#  'display',
#  'disposal',
#  'disposition',
#  'dispute',
#  'disqualification',
#  'disquisition',
#  'disregard',
#  'disrepair',
#  'disruption',
#  'dissemination',
#  'dissension',
#  'dissent',
#  'dissenting',
#  'dissipation',
#  'dissolution',
#  'distance',
#  'distant',
#  'distinction',
#  'distinguished',
#  'distress',
#  'distributer',
#  'distribution',
#  'district',
#  'distrust',
#  'disturbance',
#  'disunion',
#  'divergent',
#  'diversification',
#  'diversity',
#  'dividend',
#  'divine',
#  'division',
#  'divisiveness',
#  'divorce',
#  'dock',
#  'dockyard',
#  'doctrine',
#  'document',
#  'doer',
#  'dogma',
#  'dollar',
#  'domain',
#  'domestic',
#  'domination',
#  'dominion',
#  'don',
#  'door',
#  'doorstep',
#  'dot',
#  'doubt',
#  'doubtful',
#  'drain',
#  'drama',
#  'drawn',
#  'dread',
#  'dream',
#  'dreamed',
#  'dress',
#  'drift',
#  'drug',
#  'durability',
#  'duration',
#  'ear',
#  'earner',
#  'earnest',
#  'earnings',
#  'earth',
#  'ease',
#  'east',
#  'economy',
#  'edge',
#  'edict',
#  'education',
#  'effect',
#  'effectiveness',
#  'efficiency',
#  'efficient',
#  'effort',
#  'egypt',
#  'eject',
#  'elasticity',
#  'elder',
#  'election',
#  'elective',
#  'elector',
#  'electorate',
#  'element',
#  'elevat',
#  'elevation',
#  'eligibility',
#  'elimination',
#  'eloquence',
#  'em',
#  'emancipation',
#  'embarrassment',
#  'emergency',
#  'emigrant',
#  'eminence',
#  'eminent',
#  'emolument',
#  'emotion',
#  'emperor',
#  'emphasis',
#  'empire',
#  'employ',
#  'employee',
#  'employer',
#  ...]

# %%
var
# Out:
# [Empty DataFrame
#  Columns: [abandonment, abeyance, ability, abode, abraham, absence, absent, absolute, abstraction, abundance, abuse, academy, accept, acceptance, access, accession, accident, accommodation, accomplishment, accord, accordance, account, accountability, accumulation, achievement, acknowledgment, acquiescence, acquisition, act, action, activism, activity, addiction, addition, address, adequate, adherence, adheres, adjunct, adjustment, administration, administrator, admiration, admission, admonition, adoption, adorns, advance, advancement, advantage, adventure, adversary, adverse, advice, adviser, advocacy, advocate, aegis, affair, affection, affectionate, affiliation, affirmation, affirms, affliction, afford, afghanistan, afield, afloat, aftermath, age, agency, agent, aggrandizement, aggravation, aggregate, aggression, aggressor, agitate, agitation, agony, agreement, agriculture, aid, aim, air, airport, alacrity, alarm, alien, alienation, aliment, ality, allegation, alleghanies, allegiance, alleviate, alliance, allusion, ally, ...]
#  Index: []
#
#  [0 rows x 3214 columns]]

# %%
from gensim.test.utils import common_texts
from gensim.corpora.dictionary import Dictionary

print(common_texts)

# Create a corpus from a list of texts
dictionary = Dictionary(common_texts)
corpus = [common_dictionary.doc2bow(text) for text in common_texts]

print(dictionary, "\n")
print(common_dictionary, "\n")
print(common_texts, "\n")
print(corpus)

# Train the model on the corpus.
lda = LdaModel(corpus, num_topics=10)
# Out:
# [['human', 'interface', 'computer'], ['survey', 'user', 'computer', 'system', 'response', 'time'], ['eps', 'user', 'interface', 'system'], ['system', 'human', 'system', 'eps'], ['user', 'response', 'time'], ['trees'], ['graph', 'trees'], ['graph', 'minors', 'trees'], ['graph', 'minors', 'survey']]
# Dictionary(12 unique tokens: ['computer', 'human', 'interface', 'response', 'survey']...)
#
# Dictionary(12 unique tokens: ['computer', 'human', 'interface', 'response', 'survey']...)
#
# [['human', 'interface', 'computer'], ['survey', 'user', 'computer', 'system', 'response', 'time'], ['eps', 'user', 'interface', 'system'], ['system', 'human', 'system', 'eps'], ['user', 'response', 'time'], ['trees'], ['graph', 'trees'], ['graph', 'minors', 'trees'], ['graph', 'minors', 'survey']]
#
# [[(0, 1), (1, 1), (2, 1)], [(0, 1), (3, 1), (4, 1), (5, 1), (6, 1), (7, 1)], [(2, 1), (5, 1), (7, 1), (8, 1)], [(1, 1), (5, 2), (8, 1)], [(3, 1), (6, 1), (7, 1)], [(9, 1)], [(9, 1), (10, 1)], [(9, 1), (10, 1), (11, 1)], [(4, 1), (10, 1), (11, 1)]]

# %%
import numpy 

from gensim.test.utils import common_texts, common_dictionary
from gensim.corpora.dictionary import Dictionary
from gensim.models import LdaModel

print(numpy.array(common_texts).shape)
print(numpy.array(common_dictionary).shape)

ct = text.split(' ')
cd = ['citizen', 'oath', 'countryman', 'world', 'duty','president']

# Create a corpus from a list of texts
dictionary = Dictionary(common_texts)
corpus = [cd for text in common_texts]

# Train the model on the corpus.
lda = LdaModel(corpus, num_topics=10)

lda.fit(X_train, y_train)

from sklearn.metrics import classification_report
print(classification_report(ytest, ytrain[:6]))
# Out:
# (9,)
# (12,)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-bdefc7bffdc8> in <module>()
#      16
#      17 # Train the model on the corpus.
# ---> 18 lda = LdaModel(corpus, num_topics=10)
#      19
#      20 lda.fit(X_train, y_train)
#
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py in __init__(self, corpus, num_topics, id2word, distributed, chunksize, passes, update_every, alpha, eta, decay, offset, eval_every, iterations, gamma_threshold, minimum_probability, random_state, ns_conf, minimum_phi_value, per_word_topics, callbacks, dtype)
#     427         if self.id2word is None:
#     428             logger.warning("no word id mapping provided; initializing from corpus, assuming identity")
# --> 429             self.id2word = utils.dict_from_corpus(corpus)
#     430             self.num_terms = len(self.id2word)
#     431         elif len(self.id2word) > 0:
#
# /usr/local/lib/python3.7/dist-packages/gensim/utils.py in dict_from_corpus(corpus)
#     813
#     814     """
# --> 815     num_terms = 1 + get_max_id(corpus)
#     816     id2word = FakeDict(num_terms)
#     817     return id2word
#
# /usr/local/lib/python3.7/dist-packages/gensim/utils.py in get_max_id(corpus)
#     723     maxid = -1
#     724     for document in corpus:
# --> 725         maxid = max(maxid, max([-1] + [fieldid for fieldid, _ in document]))  # [-1] to avoid exceptions from max(empty)
#     726     return maxid
#     727
#
# /usr/local/lib/python3.7/dist-packages/gensim/utils.py in <listcomp>(.0)
#     723     maxid = -1
#     724     for document in corpus:
# --> 725         maxid = max(maxid, max([-1] + [fieldid for fieldid, _ in document]))  # [-1] to avoid exceptions from max(empty)
#     726     return maxid
#     727
#
# ValueError: too many values to unpack (expected 2)

# %%
from gensim.test.utils import common_texts
from gensim.corpora.dictionary import Dictionary

# Create a corpus from a list of texts
dictionary = Dictionary(common_texts)
corpus = [common_dictionary.doc2bow(text) for text in common_texts]

# Train the model on the corpus.
lda = LdaModel(corpus, num_topics=10)

# %%
# confusion matrix in sklearn
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# actual values
actual = [1,0,0,1,0,0,1,0,0,1]
# predicted values
predicted = [1,0,0,1,0,0,0,1,0,0]

# confusion matrix
matrix = confusion_matrix(actual,predicted, labels=[1,0])
print('Confusion matrix : \n',matrix)

# outcome values order in sklearn
tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
print('Outcome values : \n', tp, fn, fp, tn)

# classification report for precision, recall f1-score and accuracy
matrix = classification_report(actual,predicted,labels=[1,0])
print('Classification report : \n',matrix)

# %% [markdown]
# ## lda2vec

# %%
model = LDA2Vec(n_words, max_length, n_hidden, counts)
model.add_component(n_docs, n_topics, name='document id')
model.fit(clean, components=[doc_ids])
topics = model.prepare_topics('document_id', vocab)
prepared = pyLDAvis.prepare(topics)
pyLDAvis.display(prepared)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-78-9b33303b1365> in <module>()
# ----> 1 model = LDA2Vec(n_words, max_length, n_hidden, counts)
#       2 model.add_component(n_docs, n_topics, name='document id')
#       3 model.fit(clean, components=[doc_ids])
#       4 topics = model.prepare_topics('document_id', vocab)
#       5 prepared = pyLDAvis.prepare(topics)
#
# NameError: name 'LDA2Vec' is not defined

# %% [markdown]
# ## LSA

# %%
from gensim.test.utils import common_dictionary, common_corpus
from gensim.models import LsiModel

model = LsiModel(common_corpus, id2word=common_dictionary)
vectorized_corpus = model[common_corpus]

# %%
print(type(model))
# Out:
# <class 'gensim.models.lsimodel.LsiModel'>

# %%
model = LsiModel(common_corpus, id2word=common_dictionary)
W = model.fit_transform(X)
# print("W:\n", W)
H = model.fit_transform(ytest)

matrix = classification_report(W[:6], H, labels=[1,0])
print('Classification report : \n',matrix)
